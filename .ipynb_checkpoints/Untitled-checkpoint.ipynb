# %%
from requests import get
from bs4 import BeautifulSoup
url = 'https://trak.in/india-startup-funding-investment-2015/'
response = get(url)
html_soup = BeautifulSoup(response.text, 'html.parser')
movie_containers = html_soup.find_all('table', class_='tablepress tablepress-id-46')
print(movie_containers)
# Out:
#  <!DOCTYPE html>
# <!--[if IE 8]>
# 	<html class="ie ie8" lang="en-US"> <![endif]-->
# <!--[if IE 9]>
# 	<html class="ie ie9" lang="en-US"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="UTF-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <link rel="pingback" href="https://trak.in/xmlrpc.php" />
# <title>Indian Startup Funding And Investment Chart [2018]</title>
#
# <meta name="description" content="A Complete list of over 2500 Indian Startup Funding &amp; Investment deals struck since 2015 till date (2018). The list offers full Chronological month-wise details of all Funding &amp; Investment deals happened in India." />
# <meta name="robots" content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" />
# <link rel="canonical" href="https://trak.in/india-startup-funding-investment/" />
# <meta property="og:locale" content="en_US" />
# <meta property="og:type" content="article" />
# <meta property="og:title" content="Indian Startup Funding And Investment Chart [2018]" />
# <meta property="og:description" content="A Complete list of over 3000 Indian Startup Funding &amp; Investment deals struck since 2015 till date (2018). The list offers full Chronological month-wise details of all Funding &amp; Investment deals happened in India." />
# <meta property="og:url" content="https://trak.in/india-startup-funding-investment/" />
# <meta property="og:site_name" content="Trak.in - Indian Business of Tech, Mobile &amp; Startups" />
# <meta property="article:publisher" content="http://www.facebook.com/IndiaBusinessBlog" />
# <meta property="og:image" content="https://trak.in/wp-content/uploads/2016/04/Indian-Startup-Funding-Investment-Chart-2016.jpg" />
# <meta property="og:image:secure_url" content="https://trak.in/wp-content/uploads/2016/04/Indian-Startup-Funding-Investment-Chart-2016.jpg" />
# <meta property="og:image:width" content="1201" />
# <meta property="og:image:height" content="573" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:description" content="A Complete list of over 3000 Indian Startup Funding &amp; Investment deals struck since 2015 till date (2018). The list offers full Chronological month-wise details of all Funding &amp; Investment deals happened in India." />
# <meta name="twitter:title" content="Indian Startup Funding And Investment Chart [2018]" />
# <meta name="twitter:site" content="@trakin" />
# <meta name="twitter:image" content="https://trak.in/wp-content/uploads/2016/04/Indian-Startup-Funding-Investment-Chart-2016.jpg" />
# <meta name="twitter:creator" content="@trakin" />
# <script type='application/ld+json' class='yoast-schema-graph yoast-schema-graph--main'>{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://trak.in/#website","url":"https://trak.in/","name":"Trak.in - Indian Business of Tech, Mobile &amp; Startups","potentialAction":{"@type":"SearchAction","target":"https://trak.in/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"ImageObject","@id":"https://trak.in/india-startup-funding-investment-2015/#primaryimage","url":"https://trak.in/wp-content/uploads/2017/03/Indian-Startup-Funding-Investment-Chart-2017.jpg","width":1000,"height":500,"caption":"Indian Startup Funding & Investment Chart 2017"},{"@type":"WebPage","@id":"https://trak.in/india-startup-funding-investment-2015/#webpage","url":"https://trak.in/india-startup-funding-investment-2015/","inLanguage":"en-US","name":"Indian Startup Funding And Investment Chart [2018]","isPartOf":{"@id":"https://trak.in/#website"},"primaryImageOfPage":{"@id":"https://trak.in/india-startup-funding-investment-2015/#primaryimage"},"datePublished":"2017-09-03T06:10:16+00:00","dateModified":"2020-05-26T03:46:11+00:00","description":"A Complete list of over 2500 Indian Startup Funding & Investment deals struck since 2015 till date (2018). The list offers full Chronological month-wise details of all Funding & Investment deals happened in India.","breadcrumb":{"@id":"https://trak.in/india-startup-funding-investment-2015/#breadcrumb"}},{"@type":"BreadcrumbList","@id":"https://trak.in/india-startup-funding-investment-2015/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https://trak.in/","url":"https://trak.in/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@type":"WebPage","@id":"https://trak.in/india-startup-funding-investment-2015/","url":"https://trak.in/india-startup-funding-investment-2015/","name":"Indian Startup Funding and Investment Chart 2017"}}]}]}</script>
#
# <link rel="amphtml" href="https://trak.in/india-startup-funding-investment-2015/amp/" /><meta name="generator" content="AMP for WP 1.0.31" /><link rel='dns-prefetch' href='//s0.wp.com' />
# <link rel='dns-prefetch' href='//fonts.googleapis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Trak.in - Indian Business of Tech, Mobile &amp; Startups &raquo; Feed" href="https://trak.in/feed/" />
# <link rel="alternate" type="application/rss+xml" title="Trak.in - Indian Business of Tech, Mobile &amp; Startups &raquo; Comments Feed" href="https://trak.in/comments/feed/" />
# <link rel="alternate" type="application/rss+xml" title="Trak.in - Indian Business of Tech, Mobile &amp; Startups &raquo; Indian Startup Funding And Investment Chart [2020] Comments Feed" href="https://trak.in/india-startup-funding-investment-2015/feed/" />
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11.2.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11.2.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/trak.in\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.1.5"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='wp-block-library-css' href='https://trak.in/wp-includes/css/dist/block-library/style.min.css?ver=5.1.5' type='text/css' media='all' />
# <link rel='stylesheet' id='rs-plugin-settings-css' href='https://trak.in/wp-content/plugins/revslider/public/assets/css/rs6.css?ver=6.1.5' type='text/css' media='all' />
# <style id='rs-plugin-settings-inline-css' type='text/css'>
# #rs-demo-id {}
# </style>
# <link rel='stylesheet' id='toc-screen-css' href='https://trak.in/wp-content/plugins/table-of-contents-plus/screen.min.css?ver=2002' type='text/css' media='all' />
# <link rel='stylesheet' id='tablepress-default-css' href='https://trak.in/wp-content/plugins/tablepress/css/default.min.css?ver=1.9.2' type='text/css' media='all' />
# <link rel='stylesheet' id='js_composer_front-css' href='https://trak.in/wp-content/plugins/js_composer/assets/css/js_composer.min.css?ver=6.1' type='text/css' media='all' />
# <link rel='stylesheet' id='publisher-child-css' href='https://trak.in/wp-content/themes/publisher-child/style.css?ver=1.0.0' type='text/css' media='all' />
# <link rel='stylesheet' id='better-framework-main-fonts-css' href='https://fonts.googleapis.com/css?family=Lato:400,700%7CRoboto:400,500,400italic%7CArmata:400' type='text/css' media='all' />
# <link rel='stylesheet' id='jetpack_css-css' href='https://trak.in/wp-content/plugins/jetpack/css/jetpack.css?ver=7.9.1' type='text/css' media='all' />
# <script>if (document.location.protocol != "https:") {document.location = document.URL.replace(/^http:/i, "https:");}</script><script type='text/javascript' src='https://trak.in/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script>
# <script type='text/javascript' src='https://trak.in/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/revslider/public/assets/js/revolution.tools.min.js?ver=6.0'></script>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/revslider/public/assets/js/rs6.min.js?ver=6.1.5'></script>
# <!--[if lt IE 9]>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/better-adsmanager/includes/libs/better-framework/assets/js/html5shiv.min.js?ver=3.10.16'></script>
# <![endif]-->
# <!--[if lt IE 9]>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/better-adsmanager/includes/libs/better-framework/assets/js/respond.min.js?ver=3.10.16'></script>
# <![endif]-->
# <link rel='https://api.w.org/' href='https://trak.in/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://trak.in/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://trak.in/wp-includes/wlwmanifest.xml" />
# <meta name="generator" content="WordPress 5.1.5" />
# <link rel='shortlink' href='https://trak.in/?p=35822' />
# <link rel="alternate" type="application/json+oembed" href="https://trak.in/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftrak.in%2Findia-startup-funding-investment-2015%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://trak.in/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftrak.in%2Findia-startup-funding-investment-2015%2F&#038;format=xml" />
# <!-- google_ad_section_start(weight=ignore) -->
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:896663,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# </script><meta property="fb:app_id" content="217623908263254"><meta name="generator" content="Powered by WPBakery Page Builder - drag and drop page builder for WordPress." />
# <style type="text/css">.broken_link, a.broken_link {
# 	text-decoration: line-through;
# }</style><script type="application/ld+json">{
#     "@context": "http:\/\/schema.org\/",
#     "@type": "Organization",
#     "@id": "#organization",
#     "logo": {
#         "@type": "ImageObject",
#         "url": "https:\/\/trak.in\/wp-content\/uploads\/2017\/07\/Trak-Logo-Underline-small.png"
#     },
#     "url": "https:\/\/trak.in\/",
#     "name": "Trak.in - Indian Business of Tech, Mobile &amp; Startups",
#     "description": "Trak.in is a popular Indian Business, Technology, Mobile &amp; Startup blog featuring trending News, views and analytical take on Technology, Business, Finance, Telecom, Mobile, startups &amp; Social Media Space"
# }</script>
# <script type="application/ld+json">{
#     "@context": "http:\/\/schema.org\/",
#     "@type": "WebSite",
#     "name": "Trak.in - Indian Business of Tech, Mobile &amp; Startups",
#     "alternateName": "Trak.in is a popular Indian Business, Technology, Mobile &amp; Startup blog featuring trending News, views and analytical take on Technology, Business, Finance, Telecom, Mobile, startups &amp; Social Media Space",
#     "url": "https:\/\/trak.in\/"
# }</script>
# <script type="application/ld+json">{
#     "@context": "http:\/\/schema.org\/",
#     "@type": "WebPage",
#     "headline": "Indian Startup Funding And Investment Chart [2020]",
#     "author": {
#         "@type": "Person",
#         "@id": "#person-EditorialStaff",
#         "name": "Editorial Staff"
#     },
#     "image": {
#         "@type": "ImageObject",
#         "url": "https:\/\/trak.in\/wp-content\/uploads\/2017\/03\/Indian-Startup-Funding-Investment-Chart-2017.jpg",
#         "width": 1000,
#         "height": 500
#     },
#     "interactionStatistic": [
#         {
#             "@type": "InteractionCounter",
#             "interactionType": "http:\/\/schema.org\/CommentAction",
#             "userInteractionCount": 199
#         }
#     ],
#     "publisher": {
#         "@id": "#organization"
#     },
#     "mainEntityOfPage": "https:\/\/trak.in\/india-startup-funding-investment-2015\/",
#     "potentialAction": {
#         "comments": {
#             "@type": "SearchAction",
#             "target": "https:\/\/trak.in\/search\/{search_term}",
#             "query-input": "required name=search_term"
#         }
#     }
# }</script>
# <link rel='stylesheet' id='bf-minifed-css-1' href='https://trak.in/wp-content/bs-booster-cache/8a3517403052003724bfb68ebe142f26.css' type='text/css' media='all' />
# <link rel='stylesheet' id='7.6.2-1590669130' href='https://trak.in/wp-content/bs-booster-cache/d5b35f2f0fb1ce1bc9c84bb4b495a8a0.css' type='text/css' media='all' />
# <meta name="generator" content="Powered by Slider Revolution 6.1.5 - responsive, Mobile-Friendly Slider Plugin for WordPress with comfortable drag and drop interface." />
# <link rel="icon" href="https://trak.in/wp-content/uploads/2016/02/cropped-Favicon-Square-2016-2-32x32.gif" sizes="32x32" />
# <link rel="icon" href="https://trak.in/wp-content/uploads/2016/02/cropped-Favicon-Square-2016-2-192x192.gif" sizes="192x192" />
# <link rel="apple-touch-icon-precomposed" href="https://trak.in/wp-content/uploads/2016/02/cropped-Favicon-Square-2016-2-180x180.gif" />
# <meta name="msapplication-TileImage" content="https://trak.in/wp-content/uploads/2016/02/cropped-Favicon-Square-2016-2-270x270.gif" />
# <script type="text/javascript">function setREVStartSize(t){try{var h,e=document.getElementById(t.c).parentNode.offsetWidth;if(e=0===e||isNaN(e)?window.innerWidth:e,t.tabw=void 0===t.tabw?0:parseInt(t.tabw),t.thumbw=void 0===t.thumbw?0:parseInt(t.thumbw),t.tabh=void 0===t.tabh?0:parseInt(t.tabh),t.thumbh=void 0===t.thumbh?0:parseInt(t.thumbh),t.tabhide=void 0===t.tabhide?0:parseInt(t.tabhide),t.thumbhide=void 0===t.thumbhide?0:parseInt(t.thumbhide),t.mh=void 0===t.mh||""==t.mh||"auto"===t.mh?0:parseInt(t.mh,0),"fullscreen"===t.layout||"fullscreen"===t.l)h=Math.max(t.mh,window.innerHeight);else{for(var i in t.gw=Array.isArray(t.gw)?t.gw:[t.gw],t.rl)void 0!==t.gw[i]&&0!==t.gw[i]||(t.gw[i]=t.gw[i-1]);for(var i in t.gh=void 0===t.el||""===t.el||Array.isArray(t.el)&&0==t.el.length?t.gh:t.el,t.gh=Array.isArray(t.gh)?t.gh:[t.gh],t.rl)void 0!==t.gh[i]&&0!==t.gh[i]||(t.gh[i]=t.gh[i-1]);var r,a=new Array(t.rl.length),n=0;for(var i in t.tabw=t.tabhide>=e?0:t.tabw,t.thumbw=t.thumbhide>=e?0:t.thumbw,t.tabh=t.tabhide>=e?0:t.tabh,t.thumbh=t.thumbhide>=e?0:t.thumbh,t.rl)a[i]=t.rl[i]<window.innerWidth?0:t.rl[i];for(var i in r=a[0],a)r>a[i]&&0<a[i]&&(r=a[i],n=i);var d=e>t.gw[n]+t.tabw+t.thumbw?1:(e-(t.tabw+t.thumbw))/t.gw[n];h=t.gh[n]*d+(t.tabh+t.thumbh)}void 0===window.rs_init_css&&(window.rs_init_css=document.head.appendChild(document.createElement("style"))),document.getElementById(t.c).height=h,window.rs_init_css.innerHTML+="#"+t.c+"_wrapper { height: "+h+"px }"}catch(t){console.log("Failure at Presize of Slider:"+t)}};</script>
# <noscript><style> .wpb_animate_when_almost_visible { opacity: 1; }</style></noscript><style>
# .ai-viewport-3                { display: none !important;}
# .ai-viewport-2                { display: none !important;}
# .ai-viewport-1                { display: inherit !important;}
# .ai-viewport-0                { display: none !important;}
# @media (min-width: 768px) and (max-width: 979px) {
# .ai-viewport-1                { display: none !important;}
# .ai-viewport-2                { display: inherit !important;}
# }
# @media (max-width: 767px) {
# .ai-viewport-1                { display: none !important;}
# .ai-viewport-3                { display: inherit !important;}
# }
# </style>
# <link href="https://plus.google.com/109875722948108811524" rel="publisher" />
# <meta name="google-site-verification" content="hxlx6ZwHDMXhIlo0FFxgevJbLWaQJlfEEK4SypfIoHk" />
# <meta name="google-site-verification" content="o_rn5bTqsMzkXk8NicyOE9blncsYgw6mHQ8SsXL1Rls" />
# <meta name="google-site-verification" content="LiYNq-cnfoQicdfX2ElvGzVNSanGLC-YEOKVVFTD3r4" />
# <script type="text/javascript">
# var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
# document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript">
# try {
# var pageTracker = _gat._getTracker("UA-6770996-2");
# pageTracker._trackPageview();
# } catch(err) {}</script>
# <script src="//cdn.izooto.com/scripts/master.1103.min.js"></script>
# <script src="//load.sumome.com/" data-sumo-site-id="f9b1a4e35eeeeb853f635abb62c7bd090d30ce1c777e82a45b0fee243a15e1b3" async="async"></script>
# <script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
# <script type='text/javascript'>
# googletag.cmd.push(function() {
# googletag.defineSlot('/1037400/Footer', [728, 90], 'div-gpt-ad-1365167472300-0').addService(googletag.pubads());
# googletag.defineSlot('/1037400/MastHead', [728, 90], 'div-gpt-ad-1365167472300-1').addService(googletag.pubads());
# googletag.defineSlot('/1037400/Sidebar-Bottom', [300, 600], 'div-gpt-ad-1365167472300-2').addService(googletag.pubads());
# googletag.defineSlot('/1037400/Sidebar-lower-middle', [300, 250], 'div-gpt-ad-1365167472300-3').addService(googletag.pubads());
# googletag.defineSlot('/1037400/Sidebar-Middle', [300, 250], 'div-gpt-ad-1365167472300-4').addService(googletag.pubads());
# googletag.defineSlot('/1037400/Sidebar-Middle-Small', [300, 100], 'div-gpt-ad-1365167472300-5').addService(googletag.pubads());
# googletag.defineSlot('/1037400/Sidebar-Top', [300, 250], 'div-gpt-ad-1365167472300-6').addService(googletag.pubads());
# googletag.defineSlot('/1037400/Left_skyscraper', [160, 600], 'div-gpt-ad-1395203885831-0').addService(googletag.pubads());
# googletag.pubads().enableSingleRequest();
# googletag.enableServices();
# });
# </script>
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#   (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-2220101849054001",
#     enable_page_level_ads: true
#   });
# </script>
# <script async custom-element="amp-auto-ads" src="https://cdn.ampproject.org/v0/amp-auto-ads-0.1.js"></script>
# </head>
# <body data-rsssl=1 class="page-template-default page page-id-35822 page-parent bs-theme bs-publisher bs-publisher-clean-magazine active-top-line ltr close-rh page-layout-3-col-0 boxed main-menu-sticky active-ajax-search  bs-hide-ha wpb-js-composer js-comp-ver-6.1 vc_responsive bs-ll-d" dir="ltr">
# <div class="main-wrap content-main-wrap">
# <header id="header" class="site-header header-style-2 boxed" itemscope="itemscope" itemtype="https://schema.org/WPHeader">
# <section class="topbar topbar-style-1 hidden-xs hidden-xs">
# <div class="content-wrap">
# <div class="container">
# <div class="topbar-inner clearfix">
# <div class="section-links">
# <div class="  better-studio-shortcode bsc-clearfix better-social-counter style-button not-colored in-4-col">
# <ul class="social-list bsc-clearfix"><li class="social-item facebook"><a href="https://www.facebook.com/IndiaBusinessBlog" target="_blank" data-wpel-link="external" rel="nofollow external noopener noreferrer"> <i class="item-icon bsfi-facebook"></i><span class="item-title"> Likes </span> </a> </li> <li class="social-item twitter"><a href="https://twitter.com/trakintech" target="_blank" data-wpel-link="external" rel="nofollow external noopener noreferrer"> <i class="item-icon bsfi-twitter"></i><span class="item-title"> Followers </span> </a> </li> <li class="social-item rss"><a href="https://trak.in/feed/rss/" target="_blank" data-wpel-link="internal"> <i class="item-icon bsfi-rss"></i><span class="item-title"> Subscribe </span> </a> </li> <li class="social-item instagram"><a href="https://instagram.com/trakintech" target="_blank" data-wpel-link="external" rel="nofollow external noopener noreferrer"> <i class="item-icon bsfi-instagram"></i><span class="item-title"> Followers </span> </a> </li> </ul>
# </div>
# </div>
# <div class="section-menu">
# <div id="menu-top" class="menu top-menu-wrapper" role="navigation" itemscope="itemscope" itemtype="https://schema.org/SiteNavigationElement">
# <nav class="top-menu-container">
# <ul id="top-navigation" class="top-menu menu clearfix bsm-pure">
# <li id="topbar-date" class="menu-item menu-item-date">
# <span class="topbar-date">Thursday, May 28, 2020</span>
# </li>
# <li id="menu-item-62524" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-title-hide better-anim-fade menu-badge-right menu-have-badge menu-item-62524"><a title="Trak.in – Indian Business Of Tech Telecom &#038; Startups" href="https://trak.in/" data-wpel-link="internal"><i class="bf-icon  fa fa-home"></i><span class="hidden">Home</span><span class="better-custom-badge">Home</span></a></li>
# <li id="menu-item-62525" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-62525"><a href="https://trak.in/about-trakin-india-business-buzz-about-me/" data-wpel-link="internal"><i class="bf-icon  fa fa-address-book-o"></i>About</a></li>
# <li id="menu-item-62526" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-62526"><a title="Get in Touch" href="https://trak.in/about-trakin-india-business-buzz-about-me/contact-me/" data-wpel-link="internal"><i class="bf-icon  fa fa-pencil-square-o"></i>TIP US</a></li>
# <li id="menu-item-62527" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-62527"><a title="Disclaimer" href="https://trak.in/disclaimer/" data-wpel-link="internal"><i class="bf-icon  fa fa-list-ul"></i>Disclaimer</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="header-inner">
# <div class="content-wrap">
# <div class="container">
# <div class="row">
# <div class="row-height">
# <div class="logo-col col-xs-4">
# <div class="col-inside">
# <div id="site-branding" class="site-branding">
# <p id="site-title" class="logo h1 img-logo">
# <a href="https://trak.in/" itemprop="url" rel="home" data-wpel-link="internal">
# <img id="site-logo" src="https://trak.in/wp-content/uploads/2017/07/Trak-Logo-Underline-small.png" alt="Trak.in" data-bsrjs="https://trak.in/wp-content/uploads/2017/07/Trak-Logo-Underline.png" />
# <span class="site-title">Trak.in - Trak.in is a popular Indian Business, Technology, Mobile &amp; Startup blog featuring trending News, views and analytical take on Technology, Business, Finance, Telecom, Mobile, startups &amp; Social Media Space</span>
# </a>
# </p>
# </div>
# </div>
# </div>
# <div class="sidebar-col col-xs-8">
# <div class="col-inside">
# <aside id="sidebar" class="sidebar" role="complementary" itemscope="itemscope" itemtype="https://schema.org/WPSideBar">
# <div class="guxo guxo-clearfix guxo-pubadban guxo-show-desktop guxo-show-tablet-landscape guxo-loc-header_aside_logo guxo-align-center guxo-column-1 guxo-hide-on-phone guxo-hide-on-tablet-portrait"><div id="guxo-62488-1891190207" class="guxo-container guxo-type-code  guxo-hide-on-tablet-portrait guxo-hide-on-phone" itemscope="" itemtype="https://schema.org/WPAdBlock" data-adid="62488" data-type="code"><div id="guxo-62488-1891190207-place"></div><script src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script><script type="text/javascript">var betterads_screen_width = document.body.clientWidth;betterads_el = document.getElementById('guxo-62488-1891190207');             if (betterads_el.getBoundingClientRect().width) {     betterads_el_width_raw = betterads_el_width = betterads_el.getBoundingClientRect().width;    } else {     betterads_el_width_raw = betterads_el_width = betterads_el.offsetWidth;    }        var size = ["125", "125"];    if ( betterads_el_width >= 728 )      betterads_el_width = ["728", "90"];    else if ( betterads_el_width >= 468 )     betterads_el_width = ["468", "60"];    else if ( betterads_el_width >= 336 )     betterads_el_width = ["336", "280"];    else if ( betterads_el_width >= 300 )     betterads_el_width = ["300", "250"];    else if ( betterads_el_width >= 250 )     betterads_el_width = ["250", "250"];    else if ( betterads_el_width >= 200 )     betterads_el_width = ["200", "200"];    else if ( betterads_el_width >= 180 )     betterads_el_width = ["180", "150"]; if ( betterads_screen_width >= 1140 ) {          document.getElementById('guxo-62488-1891190207-place').innerHTML = '<ins class="adsbygoogle" style="display:inline-block;width:728px;height:90px"  data-ad-client="ca-pub-2220101849054001"  data-ad-slot="4429244198" ></ins>';          (adsbygoogle = window.adsbygoogle || []).push({});         }else if ( betterads_screen_width >= 1019  && betterads_screen_width < 1140 ) { document.getElementById('guxo-62488-1891190207-place').innerHTML = '<ins class="adsbygoogle" style="display:inline-block;width:' + betterads_el_width[0] + 'px;height:' + betterads_el_width[1] + 'px"  data-ad-client="ca-pub-2220101849054001"  data-ad-slot="4429244198" ></ins>';         (adsbygoogle = window.adsbygoogle || []).push({});}</script></div></div> </aside>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="menu-main" class="menu main-menu-wrapper show-search-item menu-actions-btn-width-1" role="navigation" itemscope="itemscope" itemtype="https://schema.org/SiteNavigationElement">
# <div class="main-menu-inner">
# <div class="content-wrap">
# <div class="container">
# <nav class="main-menu-container">
# <ul id="main-navigation" class="main-menu menu bsm-pure clearfix">
# <li id="menu-item-62782" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-title-hide better-anim-fade menu-item-62782"><a title="Trak.in – Indian Business Of Tech Telecom &#038; Startups" href="https://trak.in/" data-wpel-link="internal"><i class="bf-icon  fa fa-home"></i><span class="hidden">Home</span></a></li>
# <li id="menu-item-19330" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-51 better-anim-none menu-item-19330"><a title="Business" href="https://trak.in/Tags/Business/category/india-business-opportunities-services-making-money/" data-wpel-link="internal"><i class="bf-icon  fa fa-line-chart"></i>Business</a></li>
# <li id="menu-item-19339" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-89 better-anim-fade menu-item-19339"><a title="Technology" href="https://trak.in/Tags/Business/category/internet/technology/" data-wpel-link="internal"><i class="bf-icon  fa fa-cloud"></i>Technology</a></li>
# <li id="menu-item-19329" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-88 better-anim-fade menu-item-19329"><a title="Internet" href="https://trak.in/Tags/Business/category/internet/" data-wpel-link="internal"><i class="bf-icon  fa fa-hashtag"></i>Internet</a></li>
# <li id="menu-item-19331" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-47 better-anim-fade menu-item-19331"><a title="Telecom" href="https://trak.in/Tags/Business/category/telecom/" data-wpel-link="internal"><i class="bf-icon  fa fa-phone"></i>Telecom</a></li>
# <li id="menu-item-19338" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-1037 better-anim-fade menu-item-19338"><a title="Mobile" href="https://trak.in/Tags/Business/category/telecom/mobile/" data-wpel-link="internal"><i class="bf-icon  fa fa-mobile"></i>mobile</a></li>
# <li id="menu-item-19332" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-52 better-anim-fade menu-item-19332"><a title="Startup &#038; Entrepreneurship" href="https://trak.in/Tags/Business/category/startup/" data-wpel-link="internal"><i class="bf-icon  fa fa-lightbulb-o"></i>Startup</a></li>
# <li id="menu-item-19337" class="menu-have-icon menu-icon-type-bs-icons menu-item menu-item-type-taxonomy menu-item-object-category menu-term-104 better-anim-fade menu-item-19337"><a title="Others" href="https://trak.in/Tags/Business/category/random/" data-wpel-link="internal"><i class="bf-icon  bsfi-flickr"></i>Others</a></li>
# <li id="menu-item-51510" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-35822 current_page_item better-anim-fade menu-item-51510"><a title="https://trak.in/india-startup-funding-investment-2015/" href="https://trak.in/india-startup-funding-investment-2015/" aria-current="page" data-wpel-link="internal"><i class="bf-icon  fa fa-dollar"></i>Funding Deals</a></li>
# <li id="menu-item-61307" class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-custom menu-item-object-custom better-anim-fade menu-item-61307"><a href="https://bit.ly/TrakinTech" data-wpel-link="external" target="_blank" rel="nofollow external noopener noreferrer"><i class="bf-icon  fa fa-video-camera"></i>Videos</a></li>
# </ul>
# <div class="menu-action-buttons width-1">
# <div class="search-container close">
# <span class="search-handler"><i class="fa fa-search"></i></span>
# <div class="search-box clearfix">
# <form role="search" method="get" class="search-form clearfix" action="https://trak.in">
# <input type="search" class="search-field" placeholder="Search..." value="" name="s" title="Search for:" autocomplete="off">
# <input type="submit" class="search-submit" value="Search">
# </form>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="rh-header clearfix dark deferred-block-exclude">
# <div class="rh-container clearfix">
# <div class="menu-container close">
# <span class="menu-handler"><span class="lines"></span></span>
# </div>
# <div class="logo-container rh-img-logo">
# <a href="https://trak.in/" itemprop="url" rel="home" data-wpel-link="internal">
# <img src="https://trak.in/wp-content/uploads/2017/07/Trak-Logo-Underline-small.png" alt="Trak.in - Indian Business of Tech, Mobile &amp; Startups" data-bsrjs="https://trak.in/wp-content/uploads/2017/07/Trak-Logo-Underline.png" /> </a>
# </div>
# </div>
# </div>
# <nav role="navigation" aria-label="Breadcrumbs" class="bf-breadcrumb clearfix bc-top-style"><div class="container bf-breadcrumb-container"><ul class="bf-breadcrumb-items" itemscope itemtype="http://schema.org/BreadcrumbList"><meta name="numberOfItems" content="2" /><meta name="itemListOrder" content="Ascending" /><li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="bf-breadcrumb-item bf-breadcrumb-begin"><a itemprop="item" href="https://trak.in" rel="home" &quot;="" data-wpel-link="internal"><span itemprop='name'>Home</span><meta itemprop="position" content="1" /></a></li><li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="bf-breadcrumb-item bf-breadcrumb-end"><span itemprop='name'>Indian Startup Funding And Investment Chart [2020]</span><meta itemprop="position" content="2" /><meta itemprop="item" content="https://trak.in/india-startup-funding-investment-2015/" /></li></ul></div></nav><main id="content" class="content-container">
# <div class="layout-3-col layout-3-col-0 layout-bc-before">
# <div class="row main-section">
# <div class="col-sm-12 content-column">
# <!-- google_ad_section_end --><!-- google_ad_section_start(weight=ignore) --><div class='code-block code-block-8 ai-viewport-2 ai-viewport-3' style='margin: 8px auto; text-align: center; display: block; clear: both;'>
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#
# <ins class="adsbygoogle" style="display:inline-block;width:320px;height:100px" data-ad-client="ca-pub-2220101849054001" data-ad-slot="3172836997"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
# <div class="single-container bs-vc-content">
# <div class="row vc_row wpb_row vc_row-fluid"><div class="bs-vc-wrapper"><div class="wpb_column bs-vc-column vc_column_container vc_col-sm-12"><div class="bs-vc-wrapper wpb_wrapper">
# <div class="wpb_text_column wpb_content_element  bs-vc-block">
# <div class="wpb_wrapper">
# <p><ins datetime="2018-03-09T05:16:43+00:00"><strong><em>[Last Updated: May 10th, 2020]</em></strong></ins></p>
# <p><strong>This page is updated frequently (once or twice in a week) </strong>and lists down all the funding and investments that have happened in since January 2016. Please note that the date mentioned is when the news of funding/investment came out and not the actual date of funding.</p>
# <p>The startup name necessarily does not denote the name of the company but the name of the product/service/website by which it is popularly known.</p><div class='code-block code-block-9 ai-viewport-3' style='margin: 8px 0; clear: both;'>
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" style="display:block" data-ad-format="fluid" data-ad-layout="image-top" data-ad-client="ca-pub-2220101849054001" data-ad-slot="6432387392"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script></div>
# <p>While we try to get the exact amount, in many cases, the funding amount is not disclosed. All amounts are converted into USD (rupee conversion at the date of news) for uniformity.</p>
# <h2><span style="font-weight: bold;">Indian Startup Funding &amp; Investment Chart [2020]</span></h2>
# <p><h2 class="tablepress-table-name tablepress-table-name-id-46">May, 2020</h2>
# <table id="tablepress-46" class="tablepress tablepress-id-46">
# <thead>
# <tr class="row-1 odd">
# <th class="column-1">Sr. No.</th><th class="column-2">Date (dd/mm/yyyy)</th><th class="column-3">Startup Name</th><th class="column-4">Industry / Vertical</th><th class="column-5">Sub-Vertical</th><th class="column-6">City / Location</th><th class="column-7">Investors' Name</th><th class="column-8">Investment Type</th><th class="column-9">Amount (In USD)</th>
# </tr>
# </thead>
# <tbody class="row-hover">
# <tr class="row-2 even">
# <td class="column-1">1</td><td class="column-2">21/05/2020</td><td class="column-3"><a href="https://leap.club/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">leap.club</a></td><td class="column-4">Professional Network for Women</td><td class="column-5">Professional Network for Women</td><td class="column-6">Gurugram</td><td class="column-7">Whiteboard Capital (Sandeep Tandon’s VC fund), FirstCheque, Artha India Ventures, Sweta Rau (Founder, White Ventures), Amrish Rau (CEO Pinelabs, Founder Citrus Pay), Deepak Abbot (Former SVP, Paytm), and Harpreet Singh Grover (Co-founder, Co-Cubes) and others.<br />
# </td><td class="column-8">Pre Seed</td><td class="column-9"><strong>340,000</strong></td>
# </tr>
# <tr class="row-3 odd">
# <td class="column-1">2</td><td class="column-2">20/05/2020</td><td class="column-3"><a href="https://www.tring.co.in/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Tring</a></td><td class="column-4">Advertising</td><td class="column-5">Celebrity Engagement Platform</td><td class="column-6">Mumbai</td><td class="column-7">Tencent, Ark Impact, KoKalyan Krishnamurthy of Flipkart, Sujeet Kumar of Udaan, Gaurav Munjal of Unacademy, Keshav Sanghi of VentureWorks India, Roman Saini of Unacademy, Hemesh Singh of Unacademy, and Sumit Jain of Opentalk amongst others. <br />
# </td><td class="column-8">Angel</td><td class="column-9"><strong>NA</strong><br />
# </td>
# </tr>
# <tr class="row-4 even">
# <td class="column-1">3</td><td class="column-2">20/05/2020</td><td class="column-3"><a href="https://khatabook.com/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Khatabook</a><br />
# </td><td class="column-4">Utility Solutions Provider</td><td class="column-5">Financial Services, Accounting, Payments. </td><td class="column-6">Bangalore</td><td class="column-7">B Capital Group, Sequoia India, Partners of DST Global, Tencent, GGV, RTP Global, Hummingbird Ventures, Falcon Edge Capital, Rocketship.vc, Unilever Ventures, Kevin Weil, Alexander Will, Kunal Shah, Kunal Bahl, and Rohit Bansal<br />
# <br />
# <br />
# </td><td class="column-8">Series B</td><td class="column-9"><strong>60,000,000</strong></td>
# </tr>
# <tr class="row-5 odd">
# <td class="column-1">4</td><td class="column-2">19/05/2020</td><td class="column-3"><a href="https://vakilsearch.com/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Vakilsearch</a></td><td class="column-4">LegalTech</td><td class="column-5">Online professional services platform for lawyers, corporate bodies, and professionals in India.</td><td class="column-6">Chennai</td><td class="column-7">Udaan co-founder, Sujeet Kumar</td><td class="column-8">Series A</td><td class="column-9"><strong>NA</strong></td>
# </tr>
# <tr class="row-6 even">
# <td class="column-1">5</td><td class="column-2">19/05/2020</td><td class="column-3"><a href="https://www.lendingkart.com/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Lendingkart</a><br />
# </td><td class="column-4">FinTech</td><td class="column-5">Financial Services, Lending, Micro Lending.</td><td class="column-6">Ahmedabad</td><td class="column-7">Fullerton Financial Holdings Pte Ltd (FFH) and Bertelsmann India Investments, Sistema Asia Fund and India Quotient. <br />
# </td><td class="column-8">Series D</td><td class="column-9"><strong>42,000,000</strong></td>
# </tr>
# <tr class="row-7 odd">
# <td class="column-1">6</td><td class="column-2">21/05/2020</td><td class="column-3"><a href="http://www.nwnt.ai/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">No Worry No Tension Healthcare (NWNT)</a></td><td class="column-4">Healthcare</td><td class="column-5">Emotional health and mental health wellness<br />
# <br />
# </td><td class="column-6">New Delhi</td><td class="column-7">Amit Burman, Chairman of Dabur India,<br />
# </td><td class="column-8">Pre Series A</td><td class="column-9"><strong>NA</strong></td>
# </tr>
# <tr class="row-8 even">
# <td class="column-1">7</td><td class="column-2">05/05/2020</td><td class="column-3"><a href="https://classplusapp.com/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Classplus</a><br />
# <br />
# </td><td class="column-4">EduTech</td><td class="column-5">e-learning, education solutions.</td><td class="column-6">Noida</td><td class="column-7">RTP Global, lume Ventures, Sequoia Capital India's Surge, Spiral Ventures, and Strive.</td><td class="column-8">Series A</td><td class="column-9"><strong>9,000,000</strong></td>
# </tr>
# <tr class="row-9 odd">
# <td class="column-1">8</td><td class="column-2">11/05/2020</td><td class="column-3"><a href="https://classplusapp.com/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Nykaa</a></td><td class="column-4">E-commerce</td><td class="column-5">Cosmetic and Beauty Products</td><td class="column-6">Mumbai</td><td class="column-7">Steadview Capital</td><td class="column-8">Series F</td><td class="column-9"><strong>8,800,000</strong></td>
# </tr>
# <tr class="row-10 even">
# <td class="column-1">9</td><td class="column-2">13/05/2020</td><td class="column-3"><a href="https://magicpin.in/india/Pune/home/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Magicpin</a></td><td class="column-4">E-commerce</td><td class="column-5">E-commerce</td><td class="column-6">Gurugram</td><td class="column-7">Lightspeed Venture Partners, along with the participation of Moonstone Investments, WaterBridge Venture, The Bunting Family Private Fund, and Srivatsan Rajan<br />
# </td><td class="column-8">Series C</td><td class="column-9"><strong>4,000,000</strong></td>
# </tr>
# <tr class="row-11 odd">
# <td class="column-1">10</td><td class="column-2">18/05/2020</td><td class="column-3"><a href="https://letstransport.in/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">LetsTransport</a></td><td class="column-4">Logistics Solution Provider</td><td class="column-5">Logistics, Transportation, Travel</td><td class="column-6">Bangalore</td><td class="column-7">InnoVen Capital</td><td class="column-8">Venture - Series Unknown</td><td class="column-9"><strong>1,700,000</strong></td>
# </tr>
# </tbody>
# </table>
# <br />
# <h2 class="tablepress-table-name tablepress-table-name-id-45">April, 2020</h2>
# <table id="tablepress-45" class="tablepress tablepress-id-45">
# <thead>
# <tr class="row-1 odd">
# <th class="column-1">Sr. No.</th><th class="column-2">Date (dd/mm/yyyy)</th><th class="column-3">Startup Name</th><th class="column-4">Industry / Vertical</th><th class="column-5">Sub-Vertical</th><th class="column-6">City / Location</th><th class="column-7">Investors' Name</th><th class="column-8">Investment Type</th><th class="column-9">Amount (In USD)</th>
# </tr>
# </thead>
# <tbody class="row-hover">
# <tr class="row-2 even">
# <td class="column-1">1</td><td class="column-2">09/04/2020</td><td class="column-3"><a href="https://www.vedantu.com/" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Vedantu</a></td><td class="column-4">EduTech</td><td class="column-5">Online Tutoring</td><td class="column-6">Bengaluru</td><td class="column-7">Legend Capital</td><td class="column-8">Series C1</td><td class="column-9"><strong>12,560,000</strong></td>
# </tr>
# <tr class="row-3 odd">
# <td class="column-1">2</td><td class="column-2">06/04/2020</td><td class="column-3"><a>Swiggy</a></td><td class="column-4">Online Food Delivery</td><td class="column-5">Online Food Delivery</td><td class="column-6">Bengaluru</td><td class="column-7">Tencent, Ark Impact, Korea Investment Partners, Samsung Ventures, and Mirae Asset Capital Markets<br />
# </td><td class="column-8">Series 1</td><td class="column-9"><strong>43,000,000</strong><br />
# </td>
# </tr>
# <tr class="row-4 even">
# <td class="column-1">3</td><td class="column-2">08/04/2020</td><td class="column-3"><a href="//www.zupee.in/”" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Zupee</a><br />
# </td><td class="column-4">Gaming</td><td class="column-5">Gaming</td><td class="column-6">Gurugram</td><td class="column-7">Matrix Partners India, Falcon Edge Capital, WestCap Group, Orios Venture Partners and Smile Group<br />
# <br />
# </td><td class="column-8">Series A</td><td class="column-9"><strong>8,000,000</strong></td>
# </tr>
# <tr class="row-5 odd">
# <td class="column-1">4</td><td class="column-2">07/04/2020</td><td class="column-3"><a href="//agrevolution.in/”" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">DeHaat</a></td><td class="column-4">AgriTech</td><td class="column-5">AgriTech</td><td class="column-6">Patna</td><td class="column-7">Sequoia Capital India, FMO, Omnivore and AgFunder.</td><td class="column-8">Series A</td><td class="column-9"><strong>12,000,000</strong></td>
# </tr>
# <tr class="row-6 even">
# <td class="column-1">5</td><td class="column-2">15/04/2020</td><td class="column-3"><a href="//www.bigbasket.com/”" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">BigBasket</a><br />
# </td><td class="column-4">E-commerce</td><td class="column-5">Online Grocery Delivery</td><td class="column-6">Bengaluru</td><td class="column-7">Alibaba Group</td><td class="column-8">Debt Financing</td><td class="column-9"><strong>50,000,000</strong></td>
# </tr>
# <tr class="row-7 odd">
# <td class="column-1">6</td><td class="column-2">08/04/2020</td><td class="column-3"><a href="//www.fingerlix.com/”" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Fingerlix</a></td><td class="column-4">Food Delivery</td><td class="column-5">Ready-to-Cook Food</td><td class="column-6">Mumbai</td><td class="column-7">Accel, Zephyr Peacock, Swiggy, and RB Investments<br />
# </td><td class="column-8">Series C</td><td class="column-9"><strong>1,800,000</strong></td>
# </tr>
# <tr class="row-8 even">
# <td class="column-1">7</td><td class="column-2">31/03/2020</td><td class="column-3"><a href="//www.nykaa.com/”" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Nykaa</a><br />
# <br />
# </td><td class="column-4">E-commerce</td><td class="column-5">Cosmetic and Beauty Products</td><td class="column-6">Mumbai</td><td class="column-7"> Steadview Capital</td><td class="column-8">Series F</td><td class="column-9"><strong>13,000,000</strong></td>
# </tr>
# <tr class="row-9 odd">
# <td class="column-1">8</td><td class="column-2">02/04/2020</td><td class="column-3"><a href="//www.recko.io/”" rel="noopener nofollow external noreferrer" target="_blank" data-wpel-link="external">Recko</a></td><td class="column-4">Digital Reconcilation and Financial Services</td><td class="column-5">AI-powered Reconciliation of Digital Transactions </td><td class="column-6">Bengaluru</td><td class="column-7">Vertex Ventures Southeast Asia and India and Prime Venture Partners</td><td class="column-8">Series A</td><td class="column-9"><strong>6,000,000</strong></td>
# </tr>
# </tbody>
# </table>
# <br />
# <h2 class="tablepress-table-name tablepress-table-name-id-44">March, 2020</h2>
# <table id="tablepress-44" class="tablepress tablepress-id-44">
# <thead>
# <tr class="row-1 odd">
# <th class="column-1">Sr. No.</th><th class="column-2">Date (dd/mm/yyyy)</th><th class="column-3">Startup Name</th><th class="column-4">Industry / Vertical</th><th class="column-5">Sub-Vertical</th><th class="column-6">City / Location</th><th class="column-7">Investors' Name</th><th class="column-8">Investment Type</th><th class="column-9">Amount (In USD)</th>
# </tr>
# </thead>
# <tbody class="row-hover">
# ...
# var publisher_theme_ajax_search_loc = {"ajax_url":"https:\/\/trak.in\/wp-admin\/admin-ajax.php","previewMarkup":"<div class=\"ajax-search-results-wrapper ajax-search-no-product ajax-search-fullwidth\">\n\t<div class=\"ajax-search-results\">\n\t\t<div class=\"ajax-ajax-posts-list\">\n\t\t\t<div class=\"clean-title heading-typo\">\n\t\t\t\t<span>Posts<\/span>\n\t\t\t<\/div>\n\t\t\t<div class=\"posts-lists\" data-section-name=\"posts\"><\/div>\n\t\t<\/div>\n\t\t<div class=\"ajax-taxonomy-list\">\n\t\t\t<div class=\"ajax-categories-columns\">\n\t\t\t\t<div class=\"clean-title heading-typo\">\n\t\t\t\t\t<span>Categories<\/span>\n\t\t\t\t<\/div>\n\t\t\t\t<div class=\"posts-lists\" data-section-name=\"categories\"><\/div>\n\t\t\t<\/div>\n\t\t\t<div class=\"ajax-tags-columns\">\n\t\t\t\t<div class=\"clean-title heading-typo\">\n\t\t\t\t\t<span>Tags<\/span>\n\t\t\t\t<\/div>\n\t\t\t\t<div class=\"posts-lists\" data-section-name=\"tags\"><\/div>\n\t\t\t<\/div>\n\t\t<\/div>\n\t<\/div>\n<\/div>","full_width":"1"};
# /* ]]> */
# </script>
# <div class="rh-cover noscroll gr-5">
# <span class="rh-close"></span>
# <div class="rh-panel rh-pm">
# <div class="rh-p-h">
# <span class="user-login">
# <span class="user-avatar user-avatar-icon"><i class="fa fa-user-circle"></i></span>
# Sign in </span> </div>
# <div class="rh-p-b">
# <div class="rh-c-m clearfix"><ul id="resp-navigation" class="resp-menu menu clearfix"><li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-title-hide better-anim-fade menu-item-62782"><a title="Trak.in – Indian Business Of Tech Telecom &#038; Startups" href="https://trak.in/" data-wpel-link="internal"><i class="bf-icon  fa fa-home"></i><span class="hidden">Home</span></a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-51 better-anim-none menu-item-19330"><a title="Business" href="https://trak.in/Tags/Business/category/india-business-opportunities-services-making-money/" data-wpel-link="internal"><i class="bf-icon  fa fa-line-chart"></i>Business</a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-89 better-anim-fade menu-item-19339"><a title="Technology" href="https://trak.in/Tags/Business/category/internet/technology/" data-wpel-link="internal"><i class="bf-icon  fa fa-cloud"></i>Technology</a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-88 better-anim-fade menu-item-19329"><a title="Internet" href="https://trak.in/Tags/Business/category/internet/" data-wpel-link="internal"><i class="bf-icon  fa fa-hashtag"></i>Internet</a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-47 better-anim-fade menu-item-19331"><a title="Telecom" href="https://trak.in/Tags/Business/category/telecom/" data-wpel-link="internal"><i class="bf-icon  fa fa-phone"></i>Telecom</a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-1037 better-anim-fade menu-item-19338"><a title="Mobile" href="https://trak.in/Tags/Business/category/telecom/mobile/" data-wpel-link="internal"><i class="bf-icon  fa fa-mobile"></i>mobile</a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-taxonomy menu-item-object-category menu-term-52 better-anim-fade menu-item-19332"><a title="Startup &#038; Entrepreneurship" href="https://trak.in/Tags/Business/category/startup/" data-wpel-link="internal"><i class="bf-icon  fa fa-lightbulb-o"></i>Startup</a></li>
# <li class="menu-have-icon menu-icon-type-bs-icons menu-item menu-item-type-taxonomy menu-item-object-category menu-term-104 better-anim-fade menu-item-19337"><a title="Others" href="https://trak.in/Tags/Business/category/random/" data-wpel-link="internal"><i class="bf-icon  bsfi-flickr"></i>Others</a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-35822 current_page_item better-anim-fade menu-item-51510"><a title="https://trak.in/india-startup-funding-investment-2015/" href="https://trak.in/india-startup-funding-investment-2015/" aria-current="page" data-wpel-link="internal"><i class="bf-icon  fa fa-dollar"></i>Funding Deals</a></li>
# <li class="menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-custom menu-item-object-custom better-anim-fade menu-item-61307"><a href="https://bit.ly/TrakinTech" data-wpel-link="external" target="_blank" rel="nofollow external noopener noreferrer"><i class="bf-icon  fa fa-video-camera"></i>Videos</a></li>
# </ul></div>
# <form role="search" method="get" class="search-form" action="https://trak.in">
# <input type="search" class="search-field" placeholder="Search..." value="" name="s" title="Search for:" autocomplete="off">
# <input type="submit" class="search-submit" value="">
# </form>
# </div>
# </div>
# <div class="rh-panel rh-p-u">
# <div class="rh-p-h">
# <span class="rh-back-menu"><i></i></span>
# </div>
# <div class="rh-p-b">
# <div id="form_69190_" class="bs-shortcode bs-login-shortcode ">
# <div class="bs-login bs-type-login" style="display:none">
# <div class="bs-login-panel bs-login-sign-panel bs-current-login-panel">
# <form name="loginform" action="https://trak.in/wp-login.php" method="post">
# <div class="login-header">
# <span class="login-icon fa fa-user-circle main-color"></span>
# <p>Welcome, Login to your account.</p>
# </div>
# <div class="login-field login-username">
# <input type="text" name="log" id="form_69190_user_login" class="input" value="" size="20" placeholder="Username or Email..." required />
# </div>
# <div class="login-field login-password">
# <input type="password" name="pwd" id="form_69190_user_pass" class="input" value="" size="20" placeholder="Password..." required />
# </div>
# <div class="login-field">
# <a href="https://trak.in/wp-login.php?action=lostpassword&amp;redirect_to=https%3A%2F%2Ftrak.in%2Findia-startup-funding-investment-2015%2F" class="go-reset-panel" data-wpel-link="internal">Forget password?</a>
# <span class="login-remember">
# <input class="remember-checkbox" name="rememberme" type="checkbox" id="form_69190_rememberme" value="forever" />
# <label class="remember-label">Remember me</label>
# </span>
# </div>
# <div class="login-field login-submit">
# <input type="submit" name="wp-submit" class="button-primary login-btn" value="Log In" />
# <input type="hidden" name="redirect_to" value="https://trak.in/india-startup-funding-investment-2015/" />
# </div>
# </form>
# </div>
# <div class="bs-login-panel bs-login-reset-panel">
# <span class="go-login-panel"><i class="fa fa-angle-left"></i> Sign in</span>
# <div class="bs-login-reset-panel-inner">
# <div class="login-header">
# <span class="login-icon fa fa-support"></span>
# <p>Recover your password.</p>
# <p>A password will be e-mailed to you.</p>
# </div>
# <form name="lostpasswordform" id="form_69190_lostpasswordform" action="https://trak.in/wp-login.php?action=lostpassword" method="post">
# <div class="login-field reset-username">
# <input type="text" name="user_login" class="input" value="" placeholder="Username or Email..." required />
# </div>
# <div class="login-field reset-submit">
# <input type="hidden" name="redirect_to" value="" />
# <input type="submit" name="wp-submit" class="login-btn" value="Send My Password" />
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type='text/javascript' charset='UTF-8' id='polldaddyRatings'><!--//--><![CDATA[//><!--
# PDRTJS_settings_8200574_page_35822={"id":8200574,"unique_id":"wp-page-35822","title":"Indian%20Startup%20Funding%20And%20Investment%20Chart%20%26%23091%3B2020%26%23093%3B","permalink":"https:\/\/trak.in\/india-startup-funding-investment-2015\/","item_id":"_page_35822"}; if ( typeof PDRTJS_RATING !== 'undefined' ){if ( typeof PDRTJS_8200574_page_35822 == 'undefined' ){PDRTJS_8200574_page_35822 = new PDRTJS_RATING( PDRTJS_settings_8200574_page_35822 );}}
# //--><!]]></script><script type='text/javascript' charset='UTF-8' src='https://polldaddy.com/js/rating/rating.js'></script><script type='text/javascript'>
# /* <![CDATA[ */
# var better_post_views_vars = {"admin_ajax_url":"https:\/\/trak.in\/wp-admin\/admin-ajax.php","post_id":"35822"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/better-post-views/js/better-post-views.min.js?ver=1.5.3'></script>
# <script type='text/javascript' src='https://s0.wp.com/wp-content/js/devicepx-jetpack.js?ver=202022'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var tocplus = {"smooth_scroll":"1","visibility_show":"show","visibility_hide":"hide","width":"Auto"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/table-of-contents-plus/front.min.js?ver=2002'></script>
# <script type='text/javascript' src='https://trak.in/wp-includes/js/comment-reply.min.js?ver=5.1.5'></script>
# <script type='text/javascript' src='https://trak.in/wp-includes/js/wp-embed.min.js?ver=5.1.5'></script>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/better-adsmanager/js/advertising.min.js?ver=1.19.2'></script>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/js_composer/assets/js/dist/js_composer_front.min.js?ver=6.1'></script>
# <script type='text/javascript' src='https://trak.in/wp-content/plugins/tablepress/js/jquery.datatables.min.js?ver=1.9.2'></script>
# <script type='text/javascript' async="async" src='https://trak.in/wp-content/bs-booster-cache/61eab096a489c03cf9d67bc1e770bbe5.js?ver=5.1.5'></script>
# <script type="text/javascript">
# jQuery(document).ready(function($){
# $('#tablepress-46').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-45').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-44').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-43').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-42').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-41').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-40').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-39').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-38').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-37').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-36').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-35').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-34').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-33').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-32').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-31').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-30').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-29').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-27').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-27-no-2').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-27-no-3').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-27-no-4').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-26').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-26-no-2').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-26-no-3').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-26-no-4').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-25').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-25-no-2').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-25-no-3').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-25-no-4').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-24').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-24-no-2').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-24-no-3').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# $('#tablepress-24-no-4').dataTable({"order":[],"orderClasses":false,"stripeClasses":["even","odd"],"pagingType":"simple","scrollX":true});
# });
# </script>
# <script>
# var guxo=function(a){"use strict";return{init:function(){0==guxo.ads_state()&&guxo.blocked_ads_fallback()},ads_state:function(){return void 0!==window.better_ads_adblock},blocked_ads_fallback:function(){var e=[];a(".guxo-container").each(function(){if("image"==a(this).data("type"))return 0;e.push({element_id:a(this).attr("id"),ad_id:a(this).data("adid")})}),e.length<1||jQuery.ajax({url:'https://trak.in/wp-admin/admin-ajax.php',type:"POST",data:{action:"better_ads_manager_blocked_fallback",ads:e},success:function(e){var t=JSON.parse(e);a.each(t.ads,function(e,t){a("#"+t.element_id).html(t.code)})}})}}}(jQuery);jQuery(document).ready(function(){guxo.init()});
#
# </script>
# <script type='text/javascript' src='https://stats.wp.com/e-202022.js' async='async' defer='defer'></script>
# <script type='text/javascript'>
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:7.9.1',blog:'1071659',post:'35822',tz:'5.5',srv:'trak.in'} ]);
# 	_stq.push([ 'clickTrackerInit', '1071659', '35822' ]);
# </script>
# <amp-auto-ads type="adsense" data-ad-client="ca-pub-2220101849054001"></amp-auto-ads>
# <img src="https://whos.amung.us/swidget/xxjx808z.gif" alt="who's online" border="0" height="1" width="1" />
# </body>
# </html>
# []
